# %% [markdown]
# <a href="https://colab.research.google.com/github/salvaderron/FDS-Assignments-24MCS008/blob/main/FDS_Assignment1_Ron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import dataset from
data=pd.read_csv('/content/drive/My Drive/assign_1.csv')

# %%
data
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Company     8
# Age        18
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
data.dtypes
# Out:
# Company     object
# Age        float64
# Salary     float64
# Place       object
# Country     object
# Gender       int64
# dtype: object

# %%
data.hist()
plt.show()

# %%
data['Company'].value_counts()
# Out:
# Company
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: count, dtype: int64

# %%
#handling missing values for company column and replacing these values with most frequently occuring values (mode)
data['Company'].fillna(data['Company'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Company     0
# Age        18
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
#handling missing values for age column and replacing these values with mean values
data['Age'].fillna(data['Age'].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Company     0
# Age         0
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %% [markdown]
# ***Checking Outliers for Columns***

# %%
sns.boxplot(data['Salary'])
plt.show()

# %%
plt.scatter(data.index, data['Salary'])
plt.xlabel('Index')
plt.ylabel('Salary')
plt.title('Scatter plot to detect outliers')
plt.show()

# %%
#handling missing values for Salary column and replacing these values with mean values
data['Salary'].fillna(data['Salary'].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Company     0
# Age         0
# Salary      0
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
data['Place']
# Out:
# 0       Chennai
# 1        Mumbai
# 2      Calcutta
# 3         Delhi
# 4        Mumbai
#          ...
# 143    Calcutta
# 144    Calcutta
# 145       Delhi
# 146      Mumbai
# 147      Cochin
# Name: Place, Length: 148, dtype: object

# %%
data['Place'].value_counts()
# Out:
# Place
# Mumbai        37
# Calcutta      33
# Chennai       14
# Delhi         14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: count, dtype: int64

# %%
sns.countplot(x='Place', data=data)
plt.xticks(rotation=90)  # Rotate labels if there are many categories
plt.show()

# %%
#handling missing values for Place column and replacing these values with most frequently occuring values (mode)
data['Place'].fillna(data['Place'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# Place      0
# Country    0
# Gender     0
# dtype: int64

# %%
data.describe()
# Out:
#               Age       Salary      Gender
# count  148.000000   148.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     10.395076  2354.305003    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     23.000000  3149.250000    0.000000
# 50%     31.000000  5312.467742    0.000000
# 75%     36.000000  7084.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
# !pip install autoviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.1
#     Uninstalling xgboost-2.1.1:
#       Successfully uninstalled xgboost-2.1.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Initialize AutoViz
AV = AutoViz_Class()

# Perform EDA
dft = AV.AutoViz(
    filename="",       # Set filename to an empty string since we're passing a DataFrame
    dfte=data,         # Pass the DataFrame directly
    depVar='',         # Specify the target variable if any, else leave empty
    verbose=2,         # Set verbosity level to 2 for detailed output
    lowess=False,
    chart_format='svg', # Set the chart format to SVG for better quality in Colab
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (148, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['Age', 'Salary']
#     Integer-Categorical Columns: []
#     String-Categorical Columns: ['Company', 'Place']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
#     Numeric-Boolean Columns: ['Gender']
#     Discrete String Columns: []
# ...
